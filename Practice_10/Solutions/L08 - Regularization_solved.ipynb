# %% [markdown]
# <img src="../../assets/logo.png" width="800">

# %% [markdown]
# Made by **Balázs Nagy** and **Márk Domokos**
#
# [<img src="../../assets/open_button.png">](https://colab.research.google.com/github/hubaycsenge/Methods_and_Tools/blob/main/Practice_10/Solutions/L08%20-%20Regularization_solved.ipynb)
#
# # Labor 08 - Regularisation of Linear Regression and Bias - Variance
#
# ### Water flow
#
# In the first part of the exercise, a linear regression is implemented to predict the amount of water spilled from a tank based on how much water is in the tank. In the second half of the exercise, we observe the debugging of the learning algorithms and the bias and variance type errors.

# %% [markdown]
# ### 1: Import, load and visualise data

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import scipy.optimize as op

# keras imports for the dataset and building our neural network
from keras.models import Sequential
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import regularizers, optimizers


from numpy.random import seed
# Since this nootebook contains a random initialization it is advised to fix the seed, to get always the same random results
seed(1)

# %% [markdown]
# ### 2: Load data

# %% [markdown]
# The data will be loaded from a publicly available file. An alternative solution would be to upload the data file directly to the google colab file system.

# %%
# !wget https://github.com/hubaycsenge/Methods_and_Tools/raw/main/assets/Lab08/Lab8data.mat
# !wget https://github.com/hubaycsenge/Methods_and_Tools/raw/main/assets/Lab08/w_final.txt
# Out:
# --2026-04-15 09:53:46--  https://github.com/hubaycsenge/Methods_and_Tools/raw/main/assets/Lab08/Lab8data.mat
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hubaycsenge/Methods_and_Tools/main/assets/Lab08/Lab8data.mat [following]
# --2026-04-15 09:53:48--  https://raw.githubusercontent.com/hubaycsenge/Methods_and_Tools/main/assets/Lab08/Lab8data.mat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1321 (1.3K) [application/octet-stream]
# Saving to: ‘Lab8data.mat.2’
#
# Lab8data.mat.2      100%[===================>]   1.29K  --.-KB/s    in 0s
#
# 2026-04-15 09:53:48 (162 MB/s) - ‘Lab8data.mat.2’ saved [1321/1321]
#
# --2026-04-15 09:53:48--  https://github.com/hubaycsenge/Methods_and_Tools/raw/main/assets/Lab08/w_final.txt
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hubaycsenge/Methods_and_Tools/main/assets/Lab08/w_final.txt [following]
# --2026-04-15 09:53:48--  https://raw.githubusercontent.com/hubaycsenge/Methods_and_Tools/main/assets/Lab08/w_final.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155 [text/plain]
# Saving to: ‘w_final.txt.2’
#
# w_final.txt.2       100%[===================>]     155  --.-KB/s    in 0s
#
# 2026-04-15 09:53:49 (3.51 MB/s) - ‘w_final.txt.2’ saved [155/155]

# %% [markdown]
# Load in the data! Use the Pandas package to do this and then convert it into a numpy array.

# %%
data = loadmat("Lab8data.mat")                         
X_train = data["X"]                                    
Y_train = data["y"]
X_val   = data["Xval"]
Y_val   = data["yval"]
X_test  = data["Xtest"]
Y_test  = data["ytest"]

del data
m,n = X_train.shape
print('Shape of X:', X_train.shape)
print('Shape of Y:', Y_train.shape)
# Out:
# Shape of X: (12, 1)
# Shape of Y: (12, 1)

# %% [markdown]
# ### 3: Visualization
#
# Let's vizualise the data set to understand it more.

# %%
plt.plot(X_train,Y_train,'x') 
plt.title('Training data')
plt.xlabel('Change in water level (X)')
plt.ylabel('Water floeing out of the dam (Y)')
plt.show()

# %% [markdown]
# Machine learning goes as far as deep learning. The limit is the single layer neural network. With this in mind, let's return to the punishment process introduced in lab L04, now using neural network packages.

# %% [markdown]
# ### Linearized regression with regularization

# %% [markdown]
# We will create a network corresponding to a linear regression, which in our case will be based on 1 input variable and will consist of 1 layer containing 1 neuron. The BIAS tag will be added naturally and a penalty tag will be added. Two commonly used penalty methods are L1 and L2.
#
# #### L2 regularisation (Ridge regression)
# $ C(w)=\frac{1}{2m}\sum_{i=1}^m(h_w(x^i)-y^i)^2+ \color{red}{\lambda\sum_{j=1}^nw_j^2} $
#
# This technique can be used to prevent over fitting. $\lambda $  should be choosen wisely. Setting it too high can result in under fitting.
#
# #### L1 regularisation (Lasso regression)
# $ C(w)=\frac{1}{2m}\sum_{i=1}^m(h_w(x^i)-y^i)^2+ \color{red}{\lambda\sum_{j=1}^n|w_j|} $
#
# This technique can also reduce certain coefficients to 0, so it is useful for input parameter selection.

# %% [markdown]
# Vizsgáljuk meg az alábbi háló összeállítást.

# %%
# Underfit Case
Lambda = 0
learning_rate_rate = 0.005
epoch = 100

# building a linear stack of layers with the sequential model
model = Sequential()
model.add(Dense(1, input_shape=(1,), use_bias=True, kernel_regularizer=regularizers.l2(Lambda)))

# compiling the sequential model
sgd = optimizers.Adam(learning_rate=learning_rate_rate)
model.compile(loss='MSE', optimizer=sgd)

# training the model and saving metrics in history
history = model.fit(X_train, Y_train, epochs=epoch, validation_data=(X_val, Y_val), verbose = 2)
# Out:
# Epoch 1/100
# 1/1 - 0s - 331ms/step - loss: 504.5508 - val_loss: 551.2638
# Epoch 2/100
# 1/1 - 0s - 44ms/step - loss: 499.4814 - val_loss: 546.0632
# Epoch 3/100
# 1/1 - 0s - 40ms/step - loss: 494.4551 - val_loss: 540.9086
# Epoch 4/100
# 1/1 - 0s - 40ms/step - loss: 489.4727 - val_loss: 535.8009
# Epoch 5/100
# 1/1 - 0s - 42ms/step - loss: 484.5348 - val_loss: 530.7408
# Epoch 6/100
# 1/1 - 0s - 47ms/step - loss: 479.6420 - val_loss: 525.7288
# Epoch 7/100
# 1/1 - 0s - 46ms/step - loss: 474.7951 - val_loss: 520.7658
# Epoch 8/100
# 1/1 - 0s - 45ms/step - loss: 469.9949 - val_loss: 515.8522
# Epoch 9/100
# 1/1 - 0s - 41ms/step - loss: 465.2416 - val_loss: 510.9886
# Epoch 10/100
# 1/1 - 0s - 39ms/step - loss: 460.5360 - val_loss: 506.1757
# Epoch 11/100
# 1/1 - 0s - 39ms/step - loss: 455.8788 - val_loss: 501.4140
# Epoch 12/100
# 1/1 - 0s - 40ms/step - loss: 451.2701 - val_loss: 496.7038
# Epoch 13/100
# 1/1 - 0s - 40ms/step - loss: 446.7108 - val_loss: 492.0457
# Epoch 14/100
# 1/1 - 0s - 40ms/step - loss: 442.2011 - val_loss: 487.4402
# Epoch 15/100
# 1/1 - 0s - 44ms/step - loss: 437.7414 - val_loss: 482.8875
# Epoch 16/100
# 1/1 - 0s - 39ms/step - loss: 433.3322 - val_loss: 478.3880
# Epoch 17/100
# 1/1 - 0s - 43ms/step - loss: 428.9738 - val_loss: 473.9421
# Epoch 18/100
# 1/1 - 0s - 39ms/step - loss: 424.6665 - val_loss: 469.5500
# Epoch 19/100
# 1/1 - 0s - 43ms/step - loss: 420.4105 - val_loss: 465.2119
# Epoch 20/100
# 1/1 - 0s - 39ms/step - loss: 416.2061 - val_loss: 460.9280
# Epoch 21/100
# 1/1 - 0s - 44ms/step - loss: 412.0536 - val_loss: 456.6985
# Epoch 22/100
# 1/1 - 0s - 42ms/step - loss: 407.9529 - val_loss: 452.5235
# Epoch 23/100
# 1/1 - 0s - 40ms/step - loss: 403.9044 - val_loss: 448.4032
# Epoch 24/100
# 1/1 - 0s - 42ms/step - loss: 399.9081 - val_loss: 444.3375
# Epoch 25/100
# 1/1 - 0s - 38ms/step - loss: 395.9641 - val_loss: 440.3265
# Epoch 26/100
# 1/1 - 0s - 40ms/step - loss: 392.0723 - val_loss: 436.3703
# Epoch 27/100
# 1/1 - 0s - 40ms/step - loss: 388.2328 - val_loss: 432.4686
# Epoch 28/100
# 1/1 - 0s - 42ms/step - loss: 384.4456 - val_loss: 428.6215
# Epoch 29/100
# 1/1 - 0s - 41ms/step - loss: 380.7106 - val_loss: 424.8288
# Epoch 30/100
# 1/1 - 0s - 39ms/step - loss: 377.0277 - val_loss: 421.0905
# Epoch 31/100
# 1/1 - 0s - 43ms/step - loss: 373.3969 - val_loss: 417.4064
# Epoch 32/100
# 1/1 - 0s - 41ms/step - loss: 369.8179 - val_loss: 413.7763
# Epoch 33/100
# 1/1 - 0s - 41ms/step - loss: 366.2906 - val_loss: 410.2000
# Epoch 34/100
# 1/1 - 0s - 41ms/step - loss: 362.8147 - val_loss: 406.6772
# Epoch 35/100
# 1/1 - 0s - 38ms/step - loss: 359.3903 - val_loss: 403.2077
# Epoch 36/100
# 1/1 - 0s - 38ms/step - loss: 356.0168 - val_loss: 399.7913
# Epoch 37/100
# 1/1 - 0s - 42ms/step - loss: 352.6942 - val_loss: 396.4276
# Epoch 38/100
# 1/1 - 0s - 54ms/step - loss: 349.4221 - val_loss: 393.1162
# Epoch 39/100
# 1/1 - 0s - 51ms/step - loss: 346.2002 - val_loss: 389.8570
# Epoch 40/100
# 1/1 - 0s - 43ms/step - loss: 343.0283 - val_loss: 386.6495
# Epoch 41/100
# 1/1 - 0s - 40ms/step - loss: 339.9060 - val_loss: 383.4934
# Epoch 42/100
# 1/1 - 0s - 38ms/step - loss: 336.8329 - val_loss: 380.3882
# Epoch 43/100
# 1/1 - 0s - 38ms/step - loss: 333.8087 - val_loss: 377.3336
# Epoch 44/100
# 1/1 - 0s - 43ms/step - loss: 330.8329 - val_loss: 374.3292
# Epoch 45/100
# 1/1 - 0s - 41ms/step - loss: 327.9054 - val_loss: 371.3745
# Epoch 46/100
# 1/1 - 0s - 39ms/step - loss: 325.0255 - val_loss: 368.4691
# Epoch 47/100
# 1/1 - 0s - 42ms/step - loss: 322.1930 - val_loss: 365.6125
# Epoch 48/100
# 1/1 - 0s - 40ms/step - loss: 319.4074 - val_loss: 362.8044
# Epoch 49/100
# 1/1 - 0s - 41ms/step - loss: 316.6683 - val_loss: 360.0441
# Epoch 50/100
# 1/1 - 0s - 41ms/step - loss: 313.9751 - val_loss: 357.3314
# Epoch 51/100
# 1/1 - 0s - 40ms/step - loss: 311.3277 - val_loss: 354.6657
# Epoch 52/100
# 1/1 - 0s - 40ms/step - loss: 308.7253 - val_loss: 352.0464
# Epoch 53/100
# 1/1 - 0s - 42ms/step - loss: 306.1676 - val_loss: 349.4732
# Epoch 54/100
# 1/1 - 0s - 42ms/step - loss: 303.6541 - val_loss: 346.9454
# Epoch 55/100
# 1/1 - 0s - 43ms/step - loss: 301.1843 - val_loss: 344.4626
# Epoch 56/100
# 1/1 - 0s - 42ms/step - loss: 298.7578 - val_loss: 342.0244
# Epoch 57/100
# 1/1 - 0s - 41ms/step - loss: 296.3741 - val_loss: 339.6301
# Epoch 58/100
# 1/1 - 0s - 46ms/step - loss: 294.0327 - val_loss: 337.2793
# Epoch 59/100
# 1/1 - 0s - 45ms/step - loss: 291.7331 - val_loss: 334.9714
# Epoch 60/100
# 1/1 - 0s - 46ms/step - loss: 289.4747 - val_loss: 332.7060
# Epoch 61/100
# 1/1 - 0s - 43ms/step - loss: 287.2572 - val_loss: 330.4825
# Epoch 62/100
# 1/1 - 0s - 40ms/step - loss: 285.0801 - val_loss: 328.3003
# Epoch 63/100
# 1/1 - 0s - 41ms/step - loss: 282.9428 - val_loss: 326.1589
# Epoch 64/100
# 1/1 - 0s - 41ms/step - loss: 280.8448 - val_loss: 324.0579
# Epoch 65/100
# 1/1 - 0s - 40ms/step - loss: 278.7856 - val_loss: 321.9967
# Epoch 66/100
# 1/1 - 0s - 41ms/step - loss: 276.7647 - val_loss: 319.9747
# Epoch 67/100
# 1/1 - 0s - 47ms/step - loss: 274.7816 - val_loss: 317.9915
# Epoch 68/100
# 1/1 - 0s - 47ms/step - loss: 272.8359 - val_loss: 316.0464
# Epoch 69/100
# 1/1 - 0s - 44ms/step - loss: 270.9270 - val_loss: 314.1390
# Epoch 70/100
# 1/1 - 0s - 43ms/step - loss: 269.0544 - val_loss: 312.2688
# Epoch 71/100
# 1/1 - 0s - 41ms/step - loss: 267.2177 - val_loss: 310.4352
# Epoch 72/100
# 1/1 - 0s - 41ms/step - loss: 265.4162 - val_loss: 308.6376
# Epoch 73/100
# 1/1 - 0s - 47ms/step - loss: 263.6495 - val_loss: 306.8756
# Epoch 74/100
# 1/1 - 0s - 39ms/step - loss: 261.9172 - val_loss: 305.1487
# Epoch 75/100
# 1/1 - 0s - 42ms/step - loss: 260.2187 - val_loss: 303.4562
# Epoch 76/100
# 1/1 - 0s - 41ms/step - loss: 258.5535 - val_loss: 301.7978
# Epoch 77/100
# 1/1 - 0s - 49ms/step - loss: 256.9211 - val_loss: 300.1729
# Epoch 78/100
# 1/1 - 0s - 49ms/step - loss: 255.3210 - val_loss: 298.5808
# Epoch 79/100
# 1/1 - 0s - 46ms/step - loss: 253.7528 - val_loss: 297.0212
# Epoch 80/100
# 1/1 - 0s - 44ms/step - loss: 252.2160 - val_loss: 295.4936
# Epoch 81/100
# 1/1 - 0s - 41ms/step - loss: 250.7100 - val_loss: 293.9974
# Epoch 82/100
# 1/1 - 0s - 42ms/step - loss: 249.2344 - val_loss: 292.5321
# Epoch 83/100
# 1/1 - 0s - 42ms/step - loss: 247.7888 - val_loss: 291.0973
# Epoch 84/100
# 1/1 - 0s - 40ms/step - loss: 246.3725 - val_loss: 289.6923
# Epoch 85/100
# 1/1 - 0s - 44ms/step - loss: 244.9852 - val_loss: 288.3168
# Epoch 86/100
# 1/1 - 0s - 43ms/step - loss: 243.6264 - val_loss: 286.9702
# Epoch 87/100
# 1/1 - 0s - 45ms/step - loss: 242.2956 - val_loss: 285.6520
# Epoch 88/100
# 1/1 - 0s - 61ms/step - loss: 240.9923 - val_loss: 284.3618
# Epoch 89/100
# 1/1 - 0s - 42ms/step - loss: 239.7161 - val_loss: 283.0991
# Epoch 90/100
# 1/1 - 0s - 39ms/step - loss: 238.4666 - val_loss: 281.8633
# Epoch 91/100
# 1/1 - 0s - 40ms/step - loss: 237.2432 - val_loss: 280.6541
# Epoch 92/100
# 1/1 - 0s - 39ms/step - loss: 236.0456 - val_loss: 279.4709
# Epoch 93/100
# 1/1 - 0s - 38ms/step - loss: 234.8732 - val_loss: 278.3133
# Epoch 94/100
# 1/1 - 0s - 39ms/step - loss: 233.7256 - val_loss: 277.1808
# Epoch 95/100
# 1/1 - 0s - 40ms/step - loss: 232.6025 - val_loss: 276.0729
# Epoch 96/100
# 1/1 - 0s - 38ms/step - loss: 231.5032 - val_loss: 274.9893
# Epoch 97/100
# 1/1 - 0s - 38ms/step - loss: 230.4275 - val_loss: 273.9294
# Epoch 98/100
# 1/1 - 0s - 42ms/step - loss: 229.3749 - val_loss: 272.8928
# Epoch 99/100
# 1/1 - 0s - 46ms/step - loss: 228.3449 - val_loss: 271.8791
# Epoch 100/100
# 1/1 - 0s - 46ms/step - loss: 227.3372 - val_loss: 270.8878

# %% [markdown]
# Let's do the prediction.

# %%
################### CODE HERE ######################## 
# Implement the prediction step.
# Use the predict() function of the model

Y_pred = model.predict(X_test)

######################################################
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# Plot the result.

# %%
plt.plot(X_train,Y_train,'x')   # adatok megjelenítése
plt.plot(X_test,Y_pred,'x', color='red')   # adatok megjelenítése
plt.title('Training data')
plt.xlabel('Change in water level (X)')
plt.ylabel('Water floeing out of the dam (Y)')
plt.legend(['Training data', 'Prediction (on Test data)'])
plt.show()

# %% [markdown]
# In line with our expectations and our simple model design, we obtained a linear estimate that does not seem to adequately capture our data. Using the built-in metrics, we can examine the running of the cost function on the training and validation data. To do this, we first plot the corresponding metrics.

# %%
# plotting the metrics
fig = plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss functions')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training loss', 'Validation loss'])

# %% [markdown]
# In the graph, we can observe that both the cost function of the training data and the cost function of the validation data remain high. Higher than one would expect from a well-functioning predictor.
#
# <img src="../../assets/Lab08/Pics/L08_HighBias.png" width="600">

# %% [markdown]
# So let's change our model to get a better result.

# %% [markdown]
# ### 4: Poly Feature

# %% [markdown]
# To get a better result, we need more input parameters. One possible way to generate more parameters is to take the polynomial coefficients of the available parameter and feed them into your neural network as additional parameters.
#
# Write a function that takes as input the matrix of actual samples and enriches it with the appropriate columns up to the desired exponent. $x => x, x^2, x^3 ... x^p$

# %%
def polyFeatures(X,p=9):
    ################### CODE HERE ######################## 
    # Implement the feature extension for the input data

    m=X.shape[0]
    X_poly = np.zeros((m,p))
    
    for i in range(1,m+1):
        for j in range(1,p+1):
            X_poly[i-1,j-1] = X[i-1, 0]**j
            
    ######################################################    
    return X_poly

# %% [markdown]
# Do not forget to lower the values, otherwise the high exponent members would distort the learning very much. Write a normalization function that takes a sample matrix as input and returns the means and variances as a vector in addition to the normalized matrix.

# %%
def featureNormalize(X):
    ################### CODE HERE ######################## 
    # Normalize the features of the input data.
    # Each features has different normalization values.

    avg = np.mean(X, axis = 0)
    X_norm = X-avg
    std = np.std(X_norm, axis = 0,ddof = 1)
    X_norm = X_norm/std
    
    ######################################################    
    return X_norm,avg,std

# %% [markdown]
# Perform both the polynomial variable enrichment and the normalization.
#
# $\color{red}{Warning!}$
#
# You should be aware of that during training you only want to use information from the training data set. This means that we should also normalise the test and validation data using the mean and standard deviation calculated from the training data. Otherwise, we would leak data back to the algorithm that could distort the learning result. The validation and test datasets thus remain truly independent and the algorithm can only work with the information obtained from the training data.

# %%
order=9

# Training data
X_train_p = polyFeatures(X_train, order)                                # polynomial features
X_train_pn, mu, sigma = featureNormalize(X_train_p)                     # feature normalization

################### CODE HERE ########################  
# Perform the feature extension and normalization for the remaining data sets as well

# Validation data
X_val_p = polyFeatures(X_val, order)
X_val_pn = (X_val_p-mu)/sigma

# Teszt data
X_test_p = polyFeatures(X_test, order)
X_test_pn = (X_test_p-mu)/sigma

###################################################### 

print("""Expected Normalized Training Example for order=3 (approx.):
[-0.362 -0.755  0.182 ]""")
print('Normalized Training Example 1:\n',X_train_pn[0,:])
# Out:
# Expected Normalized Training Example for order=3 (approx.):
# [-0.362 -0.755  0.182 ]
# Normalized Training Example 1:
#  [-0.36214078 -0.75508669  0.18222588 -0.70618991  0.30661792 -0.59087767
#   0.3445158  -0.50848117  0.35954927]

# %% [markdown]
# Set the parameters.

# %%
# Just Right Case
Lambda = 0
learning_rate_rate = 0.01
epoch = 100
optim = optimizers.SGD(learning_rate=learning_rate_rate)

# %% [markdown]
# Since we have increased the number of variables, we need to modify our model. The input layer should fit the size of our increased input matrix, but we still only want one output.

# %%
# Building a linear stack of layers with the sequential model
model2 = Sequential()

################### CODE HERE ######################## 
# Build a 2 layer Neural Network matching the input shape of the data and producing 1 output.
# Use BIAS and L2 regularization.

model2.add(Dense(order, input_shape=(order,), use_bias=True, kernel_regularizer=regularizers.l2(Lambda)))
model2.add(Dense(1))

######################################################

# %% [markdown]
# After the architecture of the model is established, the model is compiled and the cost function and the optimizer are defined. Again, there are several options to choose from, such as SGD or ADAM.

# %%
# Compiling the sequential model
# optim = optimizers.SGD(learning_rate=learning_rate_rate)
optim = optimizers.Adam(learning_rate=learning_rate_rate)
model2.compile(loss='MSE', optimizer=optim)

# Training the model and saving metrics in history
history2 = model2.fit(X_train_pn, Y_train, epochs=epoch, validation_data=(X_val_pn, Y_val), verbose = 2)
# Out:
# Epoch 1/100
# 1/1 - 0s - 435ms/step - loss: 299.0449 - val_loss: 347.3617
# Epoch 2/100
# 1/1 - 0s - 41ms/step - loss: 294.1628 - val_loss: 341.2753
# Epoch 3/100
# 1/1 - 0s - 39ms/step - loss: 289.4889 - val_loss: 335.4498
# Epoch 4/100
# 1/1 - 0s - 40ms/step - loss: 285.0146 - val_loss: 329.8633
# Epoch 5/100
# 1/1 - 0s - 45ms/step - loss: 280.7249 - val_loss: 324.4929
# Epoch 6/100
# 1/1 - 0s - 44ms/step - loss: 276.6019 - val_loss: 319.3205
# Epoch 7/100
# 1/1 - 0s - 42ms/step - loss: 272.6310 - val_loss: 314.3288
# Epoch 8/100
# 1/1 - 0s - 39ms/step - loss: 268.7993 - val_loss: 309.4956
# Epoch 9/100
# 1/1 - 0s - 41ms/step - loss: 265.0926 - val_loss: 304.7926
# Epoch 10/100
# 1/1 - 0s - 43ms/step - loss: 261.4955 - val_loss: 300.1889
# Epoch 11/100
# 1/1 - 0s - 38ms/step - loss: 257.9922 - val_loss: 295.6553
# Epoch 12/100
# 1/1 - 0s - 38ms/step - loss: 254.5671 - val_loss: 291.1664
# Epoch 13/100
# 1/1 - 0s - 39ms/step - loss: 251.2056 - val_loss: 286.7016
# Epoch 14/100
# 1/1 - 0s - 42ms/step - loss: 247.8947 - val_loss: 282.2445
# Epoch 15/100
# 1/1 - 0s - 42ms/step - loss: 244.6219 - val_loss: 277.7815
# Epoch 16/100
# 1/1 - 0s - 41ms/step - loss: 241.3759 - val_loss: 273.3009
# Epoch 17/100
# 1/1 - 0s - 40ms/step - loss: 238.1461 - val_loss: 268.7917
# Epoch 18/100
# 1/1 - 0s - 38ms/step - loss: 234.9222 - val_loss: 264.2438
# Epoch 19/100
# 1/1 - 0s - 39ms/step - loss: 231.6945 - val_loss: 259.6480
# Epoch 20/100
# 1/1 - 0s - 39ms/step - loss: 228.4538 - val_loss: 254.9957
# Epoch 21/100
# 1/1 - 0s - 38ms/step - loss: 225.1912 - val_loss: 250.2797
# Epoch 22/100
# 1/1 - 0s - 38ms/step - loss: 221.8986 - val_loss: 245.4933
# Epoch 23/100
# 1/1 - 0s - 39ms/step - loss: 218.5685 - val_loss: 240.6311
# Epoch 24/100
# 1/1 - 0s - 40ms/step - loss: 215.1938 - val_loss: 235.6891
# Epoch 25/100
# 1/1 - 0s - 42ms/step - loss: 211.7686 - val_loss: 230.6641
# Epoch 26/100
# 1/1 - 0s - 43ms/step - loss: 208.2872 - val_loss: 225.5545
# Epoch 27/100
# 1/1 - 0s - 40ms/step - loss: 204.7451 - val_loss: 220.3600
# Epoch 28/100
# 1/1 - 0s - 41ms/step - loss: 201.1385 - val_loss: 215.0815
# Epoch 29/100
# 1/1 - 0s - 39ms/step - loss: 197.4642 - val_loss: 209.7215
# Epoch 30/100
# 1/1 - 0s - 38ms/step - loss: 193.7200 - val_loss: 204.2834
# Epoch 31/100
# 1/1 - 0s - 40ms/step - loss: 189.9043 - val_loss: 198.7725
# Epoch 32/100
# 1/1 - 0s - 43ms/step - loss: 186.0163 - val_loss: 193.1948
# Epoch 33/100
# 1/1 - 0s - 45ms/step - loss: 182.0560 - val_loss: 187.5582
# Epoch 34/100
# 1/1 - 0s - 41ms/step - loss: 178.0240 - val_loss: 181.8716
# Epoch 35/100
# 1/1 - 0s - 41ms/step - loss: 173.9217 - val_loss: 176.1455
# Epoch 36/100
# 1/1 - 0s - 40ms/step - loss: 169.7511 - val_loss: 170.3919
# Epoch 37/100
# 1/1 - 0s - 40ms/step - loss: 165.5153 - val_loss: 164.6243
# Epoch 38/100
# 1/1 - 0s - 40ms/step - loss: 161.2178 - val_loss: 158.8575
# Epoch 39/100
# 1/1 - 0s - 41ms/step - loss: 156.8630 - val_loss: 153.1080
# Epoch 40/100
# 1/1 - 0s - 45ms/step - loss: 152.4561 - val_loss: 147.3939
# Epoch 41/100
# 1/1 - 0s - 45ms/step - loss: 148.0033 - val_loss: 141.7346
# Epoch 42/100
# 1/1 - 0s - 45ms/step - loss: 143.5114 - val_loss: 136.1508
# Epoch 43/100
# 1/1 - 0s - 40ms/step - loss: 138.9880 - val_loss: 130.6649
# Epoch 44/100
# 1/1 - 0s - 39ms/step - loss: 134.4416 - val_loss: 125.3003
# Epoch 45/100
# 1/1 - 0s - 40ms/step - loss: 129.8816 - val_loss: 120.0816
# Epoch 46/100
# 1/1 - 0s - 39ms/step - loss: 125.3179 - val_loss: 115.0342
# Epoch 47/100
# 1/1 - 0s - 40ms/step - loss: 120.7612 - val_loss: 110.1844
# Epoch 48/100
# 1/1 - 0s - 39ms/step - loss: 116.2227 - val_loss: 105.5587
# Epoch 49/100
# 1/1 - 0s - 39ms/step - loss: 111.7142 - val_loss: 101.1838
# Epoch 50/100
# 1/1 - 0s - 40ms/step - loss: 107.2478 - val_loss: 97.0862
# Epoch 51/100
# 1/1 - 0s - 40ms/step - loss: 102.8359 - val_loss: 93.2914
# Epoch 52/100
# 1/1 - 0s - 38ms/step - loss: 98.4909 - val_loss: 89.8240
# Epoch 53/100
# 1/1 - 0s - 39ms/step - loss: 94.2251 - val_loss: 86.7066
# Epoch 54/100
# 1/1 - 0s - 43ms/step - loss: 90.0507 - val_loss: 83.9596
# Epoch 55/100
# 1/1 - 0s - 50ms/step - loss: 85.9792 - val_loss: 81.6005
# Epoch 56/100
# 1/1 - 0s - 46ms/step - loss: 82.0218 - val_loss: 79.6433
# Epoch 57/100
# 1/1 - 0s - 39ms/step - loss: 78.1887 - val_loss: 78.0979
# Epoch 58/100
# 1/1 - 0s - 42ms/step - loss: 74.4894 - val_loss: 76.9695
# Epoch 59/100
# 1/1 - 0s - 40ms/step - loss: 70.9322 - val_loss: 76.2583
# Epoch 60/100
# 1/1 - 0s - 39ms/step - loss: 67.5246 - val_loss: 75.9589
# Epoch 61/100
# 1/1 - 0s - 42ms/step - loss: 64.2726 - val_loss: 76.0599
# Epoch 62/100
# 1/1 - 0s - 44ms/step - loss: 61.1811 - val_loss: 76.5438
# Epoch 63/100
# 1/1 - 0s - 44ms/step - loss: 58.2534 - val_loss: 77.3870
# Epoch 64/100
# 1/1 - 0s - 39ms/step - loss: 55.4917 - val_loss: 78.5592
# Epoch 65/100
# 1/1 - 0s - 38ms/step - loss: 52.8961 - val_loss: 80.0241
# Epoch 66/100
# 1/1 - 0s - 39ms/step - loss: 50.4655 - val_loss: 81.7396
# Epoch 67/100
# 1/1 - 0s - 37ms/step - loss: 48.1965 - val_loss: 83.6580
# Epoch 68/100
# 1/1 - 0s - 38ms/step - loss: 46.0839 - val_loss: 85.7277
# Epoch 69/100
# 1/1 - 0s - 38ms/step - loss: 44.1206 - val_loss: 87.8934
# Epoch 70/100
# 1/1 - 0s - 38ms/step - loss: 42.2976 - val_loss: 90.0985
# Epoch 71/100
# 1/1 - 0s - 37ms/step - loss: 40.6045 - val_loss: 92.2863
# Epoch 72/100
# 1/1 - 0s - 38ms/step - loss: 39.0297 - val_loss: 94.4018
# Epoch 73/100
# 1/1 - 0s - 38ms/step - loss: 37.5607 - val_loss: 96.3931
# Epoch 74/100
# 1/1 - 0s - 44ms/step - loss: 36.1851 - val_loss: 98.2134
# Epoch 75/100
# 1/1 - 0s - 49ms/step - loss: 34.8905 - val_loss: 99.8210
# Epoch 76/100
# 1/1 - 0s - 47ms/step - loss: 33.6655 - val_loss: 101.1810
# Epoch 77/100
# 1/1 - 0s - 44ms/step - loss: 32.4991 - val_loss: 102.2649
# Epoch 78/100
# 1/1 - 0s - 42ms/step - loss: 31.3819 - val_loss: 103.0515
# Epoch 79/100
# 1/1 - 0s - 40ms/step - loss: 30.3054 - val_loss: 103.5264
# Epoch 80/100
# 1/1 - 0s - 39ms/step - loss: 29.2623 - val_loss: 103.6820
# Epoch 81/100
# 1/1 - 0s - 39ms/step - loss: 28.2468 - val_loss: 103.5172
# Epoch 82/100
# 1/1 - 0s - 39ms/step - loss: 27.2541 - val_loss: 103.0369
# Epoch 83/100
# 1/1 - 0s - 41ms/step - loss: 26.2809 - val_loss: 102.2520
# Epoch 84/100
# 1/1 - 0s - 38ms/step - loss: 25.3250 - val_loss: 101.1778
# Epoch 85/100
# 1/1 - 0s - 38ms/step - loss: 24.3853 - val_loss: 99.8342
# Epoch 86/100
# 1/1 - 0s - 38ms/step - loss: 23.4617 - val_loss: 98.2447
# Epoch 87/100
# 1/1 - 0s - 39ms/step - loss: 22.5551 - val_loss: 96.4350
# Epoch 88/100
# 1/1 - 0s - 38ms/step - loss: 21.6670 - val_loss: 94.4327
# Epoch 89/100
# 1/1 - 0s - 39ms/step - loss: 20.7993 - val_loss: 92.2664
# Epoch 90/100
# 1/1 - 0s - 39ms/step - loss: 19.9540 - val_loss: 89.9651
# Epoch 91/100
# 1/1 - 0s - 39ms/step - loss: 19.1335 - val_loss: 87.5570
# Epoch 92/100
# 1/1 - 0s - 39ms/step - loss: 18.3398 - val_loss: 85.0697
# Epoch 93/100
# 1/1 - 0s - 38ms/step - loss: 17.5749 - val_loss: 82.5293
# Epoch 94/100
# 1/1 - 0s - 39ms/step - loss: 16.8405 - val_loss: 79.9604
# Epoch 95/100
# 1/1 - 0s - 41ms/step - loss: 16.1380 - val_loss: 77.3856
# Epoch 96/100
# 1/1 - 0s - 39ms/step - loss: 15.4685 - val_loss: 74.8254
# Epoch 97/100
# 1/1 - 0s - 39ms/step - loss: 14.8329 - val_loss: 72.2982
# Epoch 98/100
# 1/1 - 0s - 40ms/step - loss: 14.2315 - val_loss: 69.8199
# Epoch 99/100
# 1/1 - 0s - 43ms/step - loss: 13.6646 - val_loss: 67.4045
# Epoch 100/100
# 1/1 - 0s - 41ms/step - loss: 13.1320 - val_loss: 65.0633

# %% [markdown]
# After training the model, we make this prediction on our test data.

# %%
################### CODE HERE ########################
# Calculate the predictions using the recently trained model.
 
Y_pred2 = model2.predict(X_test_pn)

######################################################
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7152486a6340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %% [markdown]
# Let's plot the result of the prediction.

# %%
plt.plot(X_test,Y_pred2,'x', color="red") 
plt.plot(X_test,Y_test,'x', color="green") 
plt.title('Training data')
plt.xlabel('Change in water level (X)')
plt.ylabel('Water floeing out of the dam (Y)')
plt.legend(['Prediction', 'Test'])
plt.show()

# %% [markdown]
# You can see that the extended model gives a much better result, which fits our data much better. The result is also reflected in the metrics.

# %%
# plotting the metrics
fig = plt.figure()
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Loss functions')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train loss', 'Validation loss'])

# %% [markdown]
# Both the cost function of our training data and the cost function of our validation data were significantly lower than in our first attempt.
#
# <img src="../../assets/Lab08/Pics/L08_HighBias.png" width="600">

# %% [markdown]
# You can extend your model further and tune the hyperparameters, but be careful not to fall into the trap of over-learning, as in the model below.
#
# In our case, we chose too many input parameters and ran the learning that way.

# %%
#Overfit
Lambda = 0
learning_rate_rate = 0.001
epoch = 100
order=12
optim = optimizers.Adam(learning_rate=learning_rate_rate)

# %%
# Train
X_train_p = polyFeatures(X_train, order)                                # polynomial features
X_train_pn, mu, sigma = featureNormalize(X_train_p)                     # feature normalization

# Validation
X_val_p = polyFeatures(X_val, order)
X_val_pn = (X_val_p-mu)/sigma

# Teszt
X_test_p = polyFeatures(X_test, order)
X_test_pn = (X_test_p-mu)/sigma

# %%
# Building a linear stack of layers with the sequential model
model3 = Sequential()
model3.add(Dense(order, input_shape=(order,), use_bias=True, kernel_regularizer=regularizers.l2(Lambda)))
model3.add(Dense(1))

# %%
# compiling the sequential model
optim = optimizers.SGD(learning_rate=learning_rate_rate)
model3.compile(loss='MSE', optimizer=optim)

# training the model and saving metrics in history
history3 = model3.fit(X_train_pn, Y_train, epochs=epoch, validation_data=(X_val_pn, Y_val), verbose = 2)
# Out:
# Epoch 1/100
# 1/1 - 0s - 193ms/step - loss: 274.1856 - val_loss: 318.7057
# Epoch 2/100
# 1/1 - 0s - 43ms/step - loss: 270.9862 - val_loss: 315.1904
# Epoch 3/100
# 1/1 - 0s - 39ms/step - loss: 267.8436 - val_loss: 311.6979
# Epoch 4/100
# 1/1 - 0s - 41ms/step - loss: 264.7427 - val_loss: 308.2127
# Epoch 5/100
# 1/1 - 0s - 43ms/step - loss: 261.6703 - val_loss: 304.7214
# Epoch 6/100
# 1/1 - 0s - 39ms/step - loss: 258.6148 - val_loss: 301.2117
# Epoch 7/100
# 1/1 - 0s - 41ms/step - loss: 255.5655 - val_loss: 297.6726
# Epoch 8/100
# 1/1 - 0s - 44ms/step - loss: 252.5133 - val_loss: 294.0938
# Epoch 9/100
# 1/1 - 0s - 41ms/step - loss: 249.4496 - val_loss: 290.4665
# Epoch 10/100
# 1/1 - 0s - 40ms/step - loss: 246.3671 - val_loss: 286.7820
# Epoch 11/100
# 1/1 - 0s - 40ms/step - loss: 243.2587 - val_loss: 283.0329
# Epoch 12/100
# 1/1 - 0s - 43ms/step - loss: 240.1182 - val_loss: 279.2121
# Epoch 13/100
# 1/1 - 0s - 40ms/step - loss: 236.9401 - val_loss: 275.3132
# Epoch 14/100
# 1/1 - 0s - 42ms/step - loss: 233.7190 - val_loss: 271.3304
# Epoch 15/100
# 1/1 - 0s - 41ms/step - loss: 230.4503 - val_loss: 267.2582
# Epoch 16/100
# 1/1 - 0s - 41ms/step - loss: 227.1297 - val_loss: 263.0919
# Epoch 17/100
# 1/1 - 0s - 43ms/step - loss: 223.7532 - val_loss: 258.8273
# Epoch 18/100
# 1/1 - 0s - 39ms/step - loss: 220.3172 - val_loss: 254.4604
# Epoch 19/100
# 1/1 - 0s - 40ms/step - loss: 216.8186 - val_loss: 249.9881
# Epoch 20/100
# 1/1 - 0s - 39ms/step - loss: 213.2546 - val_loss: 245.4075
# Epoch 21/100
# 1/1 - 0s - 40ms/step - loss: 209.6225 - val_loss: 240.7167
# Epoch 22/100
# 1/1 - 0s - 43ms/step - loss: 205.9203 - val_loss: 235.9139
# Epoch 23/100
# 1/1 - 0s - 45ms/step - loss: 202.1462 - val_loss: 230.9983
# Epoch 24/100
# 1/1 - 0s - 46ms/step - loss: 198.2988 - val_loss: 225.9698
# Epoch 25/100
# 1/1 - 0s - 44ms/step - loss: 194.3772 - val_loss: 220.8287
# Epoch 26/100
# 1/1 - 0s - 40ms/step - loss: 190.3807 - val_loss: 215.5764
# Epoch 27/100
# 1/1 - 0s - 40ms/step - loss: 186.3095 - val_loss: 210.2150
# Epoch 28/100
# 1/1 - 0s - 43ms/step - loss: 182.1639 - val_loss: 204.7477
# Epoch 29/100
# 1/1 - 0s - 40ms/step - loss: 177.9449 - val_loss: 199.1783
# Epoch 30/100
# 1/1 - 0s - 42ms/step - loss: 173.6541 - val_loss: 193.5118
# Epoch 31/100
# 1/1 - 0s - 41ms/step - loss: 169.2938 - val_loss: 187.7542
# Epoch 32/100
# 1/1 - 0s - 40ms/step - loss: 164.8667 - val_loss: 181.9128
# Epoch 33/100
# 1/1 - 0s - 40ms/step - loss: 160.3765 - val_loss: 175.9955
# Epoch 34/100
# 1/1 - 0s - 40ms/step - loss: 155.8273 - val_loss: 170.0119
# Epoch 35/100
# 1/1 - 0s - 41ms/step - loss: 151.2241 - val_loss: 163.9722
# Epoch 36/100
# 1/1 - 0s - 42ms/step - loss: 146.5726 - val_loss: 157.8880
# Epoch 37/100
# 1/1 - 0s - 40ms/step - loss: 141.8794 - val_loss: 151.7719
# Epoch 38/100
# 1/1 - 0s - 42ms/step - loss: 137.1515 - val_loss: 145.6375
# Epoch 39/100
# 1/1 - 0s - 42ms/step - loss: 132.3968 - val_loss: 139.4994
# Epoch 40/100
# 1/1 - 0s - 40ms/step - loss: 127.6240 - val_loss: 133.3727
# Epoch 41/100
# 1/1 - 0s - 42ms/step - loss: 122.8421 - val_loss: 127.2737
# Epoch 42/100
# 1/1 - 0s - 40ms/step - loss: 118.0610 - val_loss: 121.2189
# Epoch 43/100
# 1/1 - 0s - 42ms/step - loss: 113.2909 - val_loss: 115.2253
# Epoch 44/100
# 1/1 - 0s - 41ms/step - loss: 108.5425 - val_loss: 109.3102
# Epoch 45/100
# 1/1 - 0s - 42ms/step - loss: 103.8266 - val_loss: 103.4908
# Epoch 46/100
# 1/1 - 0s - 41ms/step - loss: 99.1545 - val_loss: 97.7841
# Epoch 47/100
# 1/1 - 0s - 40ms/step - loss: 94.5372 - val_loss: 92.2067
# Epoch 48/100
# 1/1 - 0s - 40ms/step - loss: 89.9859 - val_loss: 86.7749
# Epoch 49/100
# 1/1 - 0s - 41ms/step - loss: 85.5116 - val_loss: 81.5037
# Epoch 50/100
# 1/1 - 0s - 42ms/step - loss: 81.1249 - val_loss: 76.4074
# Epoch 51/100
# 1/1 - 0s - 41ms/step - loss: 76.8358 - val_loss: 71.4991
# Epoch 52/100
# 1/1 - 0s - 41ms/step - loss: 72.6541 - val_loss: 66.7903
# Epoch 53/100
# 1/1 - 0s - 41ms/step - loss: 68.5885 - val_loss: 62.2914
# Epoch 54/100
# 1/1 - 0s - 41ms/step - loss: 64.6473 - val_loss: 58.0108
# Epoch 55/100
# 1/1 - 0s - 44ms/step - loss: 60.8377 - val_loss: 53.9555
# Epoch 56/100
# 1/1 - 0s - 41ms/step - loss: 57.1660 - val_loss: 50.1304
# Epoch 57/100
# 1/1 - 0s - 42ms/step - loss: 53.6376 - val_loss: 46.5389
# Epoch 58/100
# 1/1 - 0s - 40ms/step - loss: 50.2567 - val_loss: 43.1827
# Epoch 59/100
# 1/1 - 0s - 41ms/step - loss: 47.0266 - val_loss: 40.0615
# Epoch 60/100
# 1/1 - 0s - 40ms/step - loss: 43.9496 - val_loss: 37.1735
# Epoch 61/100
# 1/1 - 0s - 40ms/step - loss: 41.0266 - val_loss: 34.5154
# Epoch 62/100
# 1/1 - 0s - 39ms/step - loss: 38.2581 - val_loss: 32.0823
# Epoch 63/100
# 1/1 - 0s - 43ms/step - loss: 35.6430 - val_loss: 29.8680
# Epoch 64/100
# 1/1 - 0s - 42ms/step - loss: 33.1799 - val_loss: 27.8653
# Epoch 65/100
# 1/1 - 0s - 42ms/step - loss: 30.8661 - val_loss: 26.0657
# Epoch 66/100
# 1/1 - 0s - 41ms/step - loss: 28.6985 - val_loss: 24.4601
# Epoch 67/100
# 1/1 - 0s - 41ms/step - loss: 26.6731 - val_loss: 23.0385
# Epoch 68/100
# 1/1 - 0s - 41ms/step - loss: 24.7853 - val_loss: 21.7906
# Epoch 69/100
# 1/1 - 0s - 41ms/step - loss: 23.0303 - val_loss: 20.7054
# Epoch 70/100
# 1/1 - 0s - 40ms/step - loss: 21.4027 - val_loss: 19.7720
# Epoch 71/100
# 1/1 - 0s - 40ms/step - loss: 19.8967 - val_loss: 18.9793
# Epoch 72/100
# 1/1 - 0s - 39ms/step - loss: 18.5064 - val_loss: 18.3160
# Epoch 73/100
# 1/1 - 0s - 39ms/step - loss: 17.2259 - val_loss: 17.7714
# Epoch 74/100
# 1/1 - 0s - 39ms/step - loss: 16.0488 - val_loss: 17.3346
# Epoch 75/100
# 1/1 - 0s - 39ms/step - loss: 14.9691 - val_loss: 16.9953
# Epoch 76/100
# 1/1 - 0s - 39ms/step - loss: 13.9806 - val_loss: 16.7436
# Epoch 77/100
# 1/1 - 0s - 39ms/step - loss: 13.0774 - val_loss: 16.5700
# Epoch 78/100
# 1/1 - 0s - 39ms/step - loss: 12.2534 - val_loss: 16.4654
# Epoch 79/100
# 1/1 - 0s - 46ms/step - loss: 11.5032 - val_loss: 16.4214
# Epoch 80/100
# 1/1 - 0s - 39ms/step - loss: 10.8210 - val_loss: 16.4302
# Epoch 81/100
# 1/1 - 0s - 39ms/step - loss: 10.2018 - val_loss: 16.4843
# Epoch 82/100
# 1/1 - 0s - 40ms/step - loss: 9.6405 - val_loss: 16.5772
# Epoch 83/100
# 1/1 - 0s - 40ms/step - loss: 9.1323 - val_loss: 16.7024
# Epoch 84/100
# 1/1 - 0s - 42ms/step - loss: 8.6728 - val_loss: 16.8545
# Epoch 85/100
# 1/1 - 0s - 43ms/step - loss: 8.2578 - val_loss: 17.0284
# Epoch 86/100
# 1/1 - 0s - 42ms/step - loss: 7.8834 - val_loss: 17.2193
# Epoch 87/100
# 1/1 - 0s - 39ms/step - loss: 7.5459 - val_loss: 17.4233
# Epoch 88/100
# 1/1 - 0s - 40ms/step - loss: 7.2419 - val_loss: 17.6367
# Epoch 89/100
# 1/1 - 0s - 40ms/step - loss: 6.9683 - val_loss: 17.8563
# Epoch 90/100
# 1/1 - 0s - 40ms/step - loss: 6.7223 - val_loss: 18.0792
# Epoch 91/100
# 1/1 - 0s - 39ms/step - loss: 6.5011 - val_loss: 18.3030
# Epoch 92/100
# 1/1 - 0s - 43ms/step - loss: 6.3023 - val_loss: 18.5256
# Epoch 93/100
# 1/1 - 0s - 39ms/step - loss: 6.1236 - val_loss: 18.7452
# Epoch 94/100
# 1/1 - 0s - 40ms/step - loss: 5.9632 - val_loss: 18.9603
# Epoch 95/100
# 1/1 - 0s - 42ms/step - loss: 5.8191 - val_loss: 19.1696
# Epoch 96/100
# 1/1 - 0s - 40ms/step - loss: 5.6896 - val_loss: 19.3720
# Epoch 97/100
# 1/1 - 0s - 40ms/step - loss: 5.5732 - val_loss: 19.5668
# Epoch 98/100
# 1/1 - 0s - 39ms/step - loss: 5.4685 - val_loss: 19.7533
# Epoch 99/100
# 1/1 - 0s - 41ms/step - loss: 5.3744 - val_loss: 19.9310
# Epoch 100/100
# 1/1 - 0s - 41ms/step - loss: 5.2897 - val_loss: 20.0994

# %%
Y_pred3 = model3.predict(X_test_pn)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x715248596fc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
plt.plot(X_test,Y_pred3,'x', color="red") 
plt.plot(X_test,Y_test,'x', color="green") 
plt.title('Training data')
plt.xlabel('Change in water level (X)')
plt.ylabel('Water floeing out of the dam (Y)')
plt.legend(['Prediction', 'Test'])
plt.show()

# %%
# plotting the metrics
fig = plt.figure()
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('Loss functions')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train loss', 'Validation loss'])

# %% [markdown]
# It can be seen that the model learns too much on the training samples and after the 60th epoch the cost function of the training samples continues to decrease, but the result on the validation samples starts to deteriorate. This means that although the cost function of the training samples performs well below an expected level, the cost function of the validation and test samples will be well above the expected result. The "scissors are open", there will be a large gap between the two cost functions.
#
# <img src="../../assets/Lab08/Pics/L08_HighVariance.png" width="600">

# %% [markdown]
# ### 5: Summary and Tips
#
# Underfitting (High Bias problem):
# - Adding more input parameters to the model (either independent or polynomial).
# - $\lambda$ parameter reduction, i.e. less penalization.
# - Increase the epoch number.
# - Increase $\alpha$ (learning rate).
#
# Overfitting (High Variance problem):
# - Less input parameter.
# - Increase the $\lambda$ parameter, i.e. we penalize more.
# - More learning samples.
# - Reducing $\alpha$ (learning rate).

# %% [markdown]
# <div style="text-align: right">This lab exercise uses elements from Andrew Ng's Machine Learning course.</div>
